# %%
# %matplotlib notebook
import sys
sys.path.insert(1, '../src')

from dataset import load_dataset
from hebbiano import Hebbiano
from plotter import plot, plot_errors
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-a52a6477a1c6> in <module>
#       5 from dataset import load_dataset
#       6 from hebbiano import Hebbiano
# ----> 7 from plotter import plot, plot_errors
#
# ImportError: cannot import name 'plot_errors'

# %%
data, labels = load_dataset('../dataset/tp2_training_dataset.csv')

data_train = data[:675] # 75% de 900
labels_train = labels[:675]

data_test = data[675:]
labels_test = labels[675:]

# %%
modelo = Hebbiano(data_train)

# %%
# alg, M, lr, min_ort, max_epoch, trace = 0
def exp(lr, min_ort):
    error = modelo.train('oja', 9, lr, min_ort, 800, 100)
    y = modelo.test(data_train)
    plot(y, labels_train)
    y = modelo.test(data_test)
    plot(y, labels_test, 5)

# %%
exp(0.00001, 0.001)
# Out:
# 0.2439306054834946
# 0.01669724957308904
# 0.016445281026456166
# 0.016443840408213346
# 0.016443028091094915
# 0.016441590055776494
# 0.016441031131987947
# 0.016441295170745707
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
