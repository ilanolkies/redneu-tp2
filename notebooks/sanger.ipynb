# %%
# %matplotlib notebook
import sys
sys.path.insert(1, '../src')

# %%
from dataset import load_dataset
from hebbiano import Hebbiano
from plotter import plot, plot_error

# %%
data, labels = load_dataset('../dataset/tp2_training_dataset.csv')

data_train = data[:700]
labels_train = labels[:700]

data_test = data[700:]
labels_test = labels[700:]

# %%
modelo = Hebbiano(data_train)

# %%
errors = modelo.train('sanger', 9, 0.00001, 0.001, 4000, 100)
# Out:
# 1.5464279973064423
# 0.7175945621283116
# 0.395094101957315
# 0.32556496863957085
# 0.2727833855778452
# 0.21756674849655058
# 0.17150248793801287
# 0.1404844364804471
# 0.11837060308304286
# 0.10128150056159939
# 0.08817690703825258
# 0.078014993190584
# 0.07022997810560111
# 0.06405301602901585
# 0.05907685191875382
# 0.05497825234100793
# 0.05158690959264789
# 0.049162743786397185
# 0.047105870278868145
# 0.045327519675342334
# 0.04378522684351944
# 0.04244434682300007
# 0.04137883691163375
# 0.0405080016936674
# 0.03973844662561388
# 0.03905708259218301
# 0.03845286437632351
# 0.03791637059109916
# 0.02157344085229759
# 0.014508333673451156
# 0.011324633993917591
# 0.009787111005559887
# 0.009074433527553511
# 0.008698323372377272
# 0.008448790098780974
# 0.00826158459759537
# 0.008110725647634605
# 0.007983547092988437
# 0.007872068768320594
# 0.007777233301711638

# %%
plot_error(errors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot(modelo.test(data_train), labels_train)
# Out:
# <img src="data:image/png;base64,..." width="996">

# %%
plot(modelo.test(data_train), labels_train)
# Out:
# <img src="data:image/png;base64,..." width="1032">

# %%
modelo.save('../sanger_model.p')
