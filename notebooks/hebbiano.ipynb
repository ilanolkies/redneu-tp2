# %% [markdown]
# # Oja

# %%
# %matplotlib notebook
import sys
sys.path.insert(1, '../src')

from dataset import load_dataset
from hebbiano import Hebbiano
from plotter import plot

# %%
data, labels = load_dataset('../dataset/tp2_training_dataset.csv')

data_train = data[:675] # 75% de 900
labels_train = data[:675]

data_test = data[675:]
labels_test = data[675:]

# %%
modelo = Hebbiano(data_train)

# %%
# alg, M, lr, min_ort, max_epoch, trace = 0
modelo.train('oja', 9, 0.00001, 0.001, 600, 100)
# Out:
# 0.17627486421134397
# 0.01652537209226681
# 0.01648850399226645
# 0.016489483520849973
# 0.016485347869415877
# 0.01647797090910918

# %%
y = modelo.test(data_train)
plot(y, labels_train, 5, ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', '#73b0cd', '#9aac4d'])
# Out:
# <div id='330b3c14-cb38-4092-9628-bb1e418eea9a'></div>

# %%
y = modelo.test(data_test)
plot(y, labels_test, 3)
# Out:
# <img src="data:image/png;base64,..." width="640">
