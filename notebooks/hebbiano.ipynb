# %% [markdown]
# # Oja

# %%
# %matplotlib notebook
import sys
sys.path.insert(1, '../src')

from dataset import load_dataset
from hebbiano import Hebbiano
from plotter import plot

# %%
data, labels = load_dataset('../dataset/tp2_training_dataset.csv')

data_train = data[:675] # 75% de 900
labels_train = labels[:675]

data_test = data[675:]
labels_test = labels[675:]

# %%
modelo = Hebbiano(data_train)

# %%
# alg, M, lr, min_ort, max_epoch, trace = 0
modelo.train('oja', 9, 0.001, 0.001, 800, 100)
# Out:
# 1.7842196325765571
# 1.774560085595629
# 1.785608176609851
# 1.7844577671348765
# 1.7810037213712835
# 1.780274829768924
# 1.781130476024801
# 1.7787358364335668

# %%
y = modelo.test(data_train)
plot(y, labels_train)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y = modelo.test(data_test)
plot(y, labels_test, 5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
modelo.train('oja', 9, 0.0001, 0.001, 800, 100)
y = modelo.test(data_train)
plot(y, labels_train)
y = modelo.test(data_test)
plot(y, labels_test, 5)
# Out:
# 0.16586785861650993
# 0.16580298498137686
# 0.16572206121648225
# 0.16564230120707613
# 0.1655954649985215
# 0.16559831049963308
# 0.16558065697434662
# 0.16556279503511173
# <div id='09657cad-69c7-40f7-99ed-f0b36544ea66'></div>
# <div id='bb35b88b-1fc9-41b3-b15a-c4ea32fa2495'></div>

# %%
modelo.train('oja', 9, 0.00001, 0.001, 800, 100)
y = modelo.test(data_train)
plot(y, labels_train)
y = modelo.test(data_test)
plot(y, labels_test, 5)
