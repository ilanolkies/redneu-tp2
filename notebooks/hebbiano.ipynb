# %%
# %matplotlib notebook
import sys
sys.path.insert(1, '../src')

# %%
from dataset import load_dataset

data, labels = load_dataset('../dataset/tp2_training_dataset.csv')

data_train = data[:700]
labels_train = data[:700]

data_test = data[700:]
labels_test = data[700:]

# %%
from hebbiano import Hebbiano

modelo = Hebbiano(data_train)

# %%
modelo.train('sanger', 9, 0.001, 0.001, 600, 100)
# Out:
# 0.13632816264386854
# 0.10271653690237274
# 0.089839096786755
# 0.08247516703881787
# 0.07772283918629072
# 0.07427214446435293

# %%
y = modelo.test(data_test)

# %%
from plotter import plot

plot(y, labels_test, 3)
# Out:
# <img src="data:image/png;base64,..." width="640">
